# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./ko_pep_sim_by_period_with_corr.csv')

# %%
df.head()
# Out:
#    period ticker1 ticker2  cosine_similarity quarter  rho_mean    z_mean  \
# 0  2019Q1      KO     PEP           0.231308  2019Q1  0.696751  0.875889
# 1  2019Q2      KO     PEP           0.253259  2019Q2  0.581357  0.665360
# 2  2019Q3      KO     PEP           0.241847  2019Q3  0.568562  0.652513
# 3  2019Q4      KO     PEP           0.295962  2019Q4  0.686410  0.841447
# 4  2020Q1      KO     PEP           0.231235  2020Q1  0.791348  1.102528
#
#    n_windows  rho_from_mean_z co_mov_tickers  rolling_window_days
# 0         61         0.704354         KO-PEP                  120
# 1         63         0.581919         KO-PEP                  120
# 2         64         0.573359         KO-PEP                  120
# 3         64         0.686575         KO-PEP                  120
# 4         62         0.801405         KO-PEP                  120

# %%
df = df.drop(['n_windows','quarter','co_mov_tickers','rolling_window_days','rho_from_mean_z','z_mean'
],axis=1)

# %%
df
# Out:
#     period ticker1 ticker2  cosine_similarity  rho_mean
# 0   2019Q1      KO     PEP           0.231308  0.696751
# 1   2019Q2      KO     PEP           0.253259  0.581357
# 2   2019Q3      KO     PEP           0.241847  0.568562
# 3   2019Q4      KO     PEP           0.295962  0.686410
# 4   2020Q1      KO     PEP           0.231235  0.791348
# 5   2020Q2      KO     PEP           0.436113  0.833265
# 6   2020Q3      KO     PEP           0.455215  0.781178
# 7   2020Q4      KO     PEP           0.239286  0.614512
# 8   2021Q1      KO     PEP           0.685958  0.598719
# 9   2021Q2      KO     PEP           0.685916  0.643120
# 10  2021Q3      KO     PEP           0.679165  0.697778
# 11  2021Q4      KO     PEP           0.684128  0.737285
# 12  2022Q1      KO     PEP           0.652642  0.716461
# 13  2022Q2      KO     PEP           0.687156  0.795660
# 14  2022Q3      KO     PEP           0.661862  0.887147
# 15  2022Q4      KO     PEP           0.667157  0.860951
# ...

# %%
df.to_csv('comp_120d.csv')
